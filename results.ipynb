# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = 
print(path)
# Out:
# ~/Desktop/yolov5-torch/logs/

# %%
df_nano_half = pd.read_csv('~/Desktop/yolov5-torch/logs/yolonano/dataset_yolon_l0.csv')
df_nano_one = pd.read_csv('~/Desktop/yolov5-torch/logs/yolonano/dataset_yolon_l1.csv')
df_nano_two = pd.read_csv('~/Desktop/yolov5-torch/logs/yolonano/dataset_yolon_l2.csv')

df_nano_half.head()
# Out:
#            Time Model Name File Name  Propagation Delay (s)  \
# 0  1.712159e+09    yolov5n     6.jpg               0.128120
# 1  1.712159e+09    yolov5n     6.jpg               0.267984
# 2  1.712159e+09    yolov5n     6.jpg               0.163560
# 3  1.712159e+09    yolov5n     6.jpg               0.158425
# 4  1.712159e+09    yolov5n     6.jpg               0.266390
#
#    Processing Delay (ms)  E2E Delay (s) location  core  model_acc
# 0             902.003288       1.030109   london  half       45.7
# 1             274.723291       0.542691   london  half       45.7
# 2             809.309483       0.972852   london  half       45.7
# 3             343.733311       0.502144   london  half       45.7
# 4             578.197002       0.844565   london  half       45.7

# %%
df_nano_half.describe()
# Out:
#                Time  Propagation Delay (s)  Processing Delay (ms)  \
# count  1.000000e+03            1000.000000            1000.000000
# mean   1.712159e+09               0.334879             536.867540
# std    2.466558e+02               0.408798             218.637742
# min    1.712159e+09               0.114448             232.977390
# 25%    1.712159e+09               0.202441             331.839263
# 50%    1.712159e+09               0.239078             541.290641
# 75%    1.712159e+09               0.304533             755.115807
# max    1.712159e+09               6.668376            1196.296215
#
#        E2E Delay (s)     model_acc
# count    1000.000000  1.000000e+03
# mean        0.871726  4.570000e+01
# std         0.460337  7.108983e-15
# min         0.377330  4.570000e+01
# 25%         0.575953  4.570000e+01
# 50%         0.843823  4.570000e+01
# 75%         1.015646  4.570000e+01
# max         6.918553  4.570000e+01

# %%
df_nano_one.describe()
# Out:
#                Time  Propagation Delay (s)  Processing Delay (ms)  \
# count  1.000000e+03            1000.000000            1000.000000
# mean   1.712160e+09               0.230606             276.167738
# std    1.462655e+02               0.174261             117.688174
# min    1.712159e+09               0.110105              88.905334
# 25%    1.712160e+09               0.163567             163.687885
# 50%    1.712160e+09               0.200318             280.323267
# 75%    1.712160e+09               0.242013             384.070456
# max    1.712160e+09               3.243585             728.832483
#
#        E2E Delay (s)     model_acc
# count    1000.000000  1.000000e+03
# mean        0.506752  4.570000e+01
# std         0.209608  7.108983e-15
# min         0.208995  4.570000e+01
# 25%         0.377383  4.570000e+01
# 50%         0.498949  4.570000e+01
# 75%         0.600946  4.570000e+01
# max         3.672185  4.570000e+01

# %%
df_nano_two.describe()
# Out:
#                Time  Propagation Delay (s)  Processing Delay (ms)  \
# count  1.000000e+03            1000.000000            1000.000000
# mean   1.712158e+09               0.214642             191.818398
# std    1.170427e+02               0.159899              94.610453
# min    1.712158e+09               0.106033              86.228848
# 25%    1.712158e+09               0.157031             100.166380
# 50%    1.712158e+09               0.190455             192.362309
# 75%    1.712158e+09               0.222737             267.889082
# max    1.712158e+09               4.269720             541.697264
#
#        E2E Delay (s)     model_acc
# count    1000.000000  1.000000e+03
# mean        0.406441  4.570000e+01
# std         0.187070  7.108983e-15
# min         0.205480  4.570000e+01
# 25%         0.304378  4.570000e+01
# 50%         0.389556  4.570000e+01
# 75%         0.489221  4.570000e+01
# max         4.613516  4.570000e+01

# %%
plt.figure(figsize=(10,6))
plt.plot(df_nano_half.index[:1000], df_nano_half['Processing Delay (ms)'][:1000]/1000, label= 'Half Core - Nano')
plt.plot(df_nano_one.index[:1000], df_nano_one['Processing Delay (ms)'][:1000]/1000, label='One Core - Nano')
plt.plot(df_nano_two.index[:1000], df_nano_two['Processing Delay (ms)'][:1000]/1000, label = 'Two Core - Nano')
plt.title('Processing Delay')
plt.xlabel('Number of Requests')
plt.ylabel('Delay (ms)')
plt.legend()
plt.ylim([0,2])
plt.grid(True)
plt.show()

# %%
df_small_half = pd.read_csv('~/Desktop/yolov5-torch/logs/yolosmall/dataset_yolos_l0.csv')
df_small_one = pd.read_csv('~/Desktop/yolov5-torch/logs/yolosmall/dataset_yolos_l1.csv')
df_small_two = pd.read_csv('~/Desktop/yolov5-torch/logs/yolosmall/dataset_yolos_l2.csv')

# %%
df_small_half.describe()
# Out:
#                Time  Propagation Delay (s)  Processing Delay (ms)  \
# count  1.000000e+03            1000.000000            1000.000000
# mean   1.716401e+09               0.254891            1390.908849
# std    4.835000e+02               0.626053             344.188465
# min    1.716400e+09               0.093791             750.436544
# 25%    1.716400e+09               0.171445            1172.624111
# 50%    1.716401e+09               0.194190            1333.679080
# 75%    1.716401e+09               0.245109            1741.680384
# max    1.716402e+09              11.574706            3025.921345
#
#        E2E Delay (s)     model_acc
# count    1000.000000  1.000000e+03
# mean        1.674213  5.680000e+01
# std         0.700719  1.421797e-14
# min         0.980208  5.680000e+01
# 25%         1.414131  5.680000e+01
# 50%         1.582001  5.680000e+01
# 75%         1.966591  5.680000e+01
# max        13.189700  5.680000e+01

# %%
df_small_one.describe()
# Out:
#                Time  Propagation Delay (s)  Processing Delay (ms)  \
# count  1.000000e+03            1000.000000            1000.000000
# mean   1.716402e+09               0.171108             609.099239
# std    2.324107e+02               0.096285             151.311934
# min    1.716401e+09               0.088578             368.419170
# 25%    1.716401e+09               0.114286             476.157725
# 50%    1.716402e+09               0.136591             621.487975
# 75%    1.716402e+09               0.174644             735.519707
# max    1.716402e+09               1.170144             947.892189
#
#        E2E Delay (s)     model_acc
# count    1000.000000  1.000000e+03
# mean        0.803373  5.680000e+01
# std         0.171350  1.421797e-14
# min         0.495003  5.680000e+01
# 25%         0.663282  5.680000e+01
# 50%         0.809476  5.680000e+01
# 75%         0.917276  5.680000e+01
# max         1.828913  5.680000e+01

# %%
df_small_two.describe()
# Out:
#                Time  Propagation Delay (s)  Processing Delay (ms)  \
# count  1.000000e+03            1000.000000            1000.000000
# mean   1.716401e+09               0.167139             379.032642
# std    1.649645e+02               0.125121             123.610645
# min    1.716400e+09               0.088099             222.019196
# 25%    1.716400e+09               0.114398             254.059494
# 50%    1.716401e+09               0.132205             394.403696
# 75%    1.716401e+09               0.157205             499.000132
# max    1.716401e+09               2.384449             634.380817
#
#        E2E Delay (s)     model_acc
# count    1000.000000  1.000000e+03
# mean        0.569128  5.680000e+01
# std         0.174013  1.421797e-14
# min         0.349973  5.680000e+01
# 25%         0.412687  5.680000e+01
# 50%         0.612232  5.680000e+01
# 75%         0.661985  5.680000e+01
# max         2.662590  5.680000e+01

# %%
plt.figure(figsize=(10,6))
plt.plot(df_small_half.index[0:500], df_small_half['Processing Delay (ms)'][0:500]/1000, label= 'Half Core - Small')
plt.plot(df_small_one.index[0:500], df_small_one['Processing Delay (ms)'][0:500]/1000, label='One Core - Small')
plt.plot(df_small_two.index[0:500], df_small_two['Processing Delay (ms)'][0:500]/1000, label = 'Two Core - Small')
plt.title('Processing Delay')
plt.xlabel('Number of Requests')
plt.ylabel('Delay (ms)')
plt.legend()
plt.grid(True)
plt.show()

# %%
df_med_half = pd.read_csv('~/Desktop/yolov5-torch/logs/yolomedium/dataset_yolom_l0.csv')
df_med_one = pd.read_csv('~/Desktop/yolov5-torch/logs/yolomedium/dataset_yolom_l1.csv')
df_med_two = pd.read_csv('~/Desktop/yolov5-torch/logs/yolomedium/dataset_yolom_l2.csv')

# %%
df_med_half.describe()
# Out:
#                Time  Propagation Delay (s)  Processing Delay (ms)  \
# count  1.000000e+03            1000.000000            1000.000000
# mean   1.716487e+09               0.264432            4102.388996
# std    1.278899e+03               0.197329            1101.780689
# min    1.716485e+09               0.095633            2055.557728
# 25%    1.716486e+09               0.180554            3375.303090
# 50%    1.716487e+09               0.207840            3723.009109
# 75%    1.716488e+09               0.287340            4941.881835
# max    1.716489e+09               2.960503            7713.473558
#
#        E2E Delay (s)     model_acc
# count    1000.000000  1.000000e+03
# mean        4.394955  6.410000e+01
# std         1.130847  1.421797e-14
# min         2.321233  6.410000e+01
# 25%         3.645285  6.410000e+01
# 50%         3.985487  6.410000e+01
# 75%         5.302563  6.410000e+01
# max         8.537609  6.410000e+01

# %%
df_med_one.describe()
# Out:
#                Time  Propagation Delay (s)  Processing Delay (ms)  \
# count  1.000000e+03            1000.000000            1000.000000
# mean   1.716486e+09               0.227713            1782.567199
# std    5.811499e+02               0.244367             305.962157
# min    1.716485e+09               0.089356            1047.810316
# 25%    1.716485e+09               0.124926            1593.971252
# 50%    1.716486e+09               0.166971            1839.581251
# 75%    1.716486e+09               0.260995            1998.265862
# max    1.716487e+09               4.018124            3115.789890
#
#        E2E Delay (s)     model_acc
# count    1000.000000  1.000000e+03
# mean        2.033077  6.410000e+01
# std         0.385659  1.421797e-14
# min         1.181277  6.410000e+01
# 25%         1.811377  6.410000e+01
# 50%         2.060919  6.410000e+01
# 75%         2.232318  6.410000e+01
# max         5.696187  6.410000e+01

# %%
df_med_two.describe()
# Out:
#                Time  Propagation Delay (s)  Processing Delay (ms)  \
# count  1.000000e+03            1000.000000            1000.000000
# mean   1.716485e+09               0.165874             688.511084
# std    2.543560e+02               0.115107             107.614816
# min    1.716485e+09               0.086359             486.189365
# 25%    1.716485e+09               0.110111             590.964735
# 50%    1.716485e+09               0.131745             704.810262
# 75%    1.716486e+09               0.164580             769.679010
# max    1.716486e+09               1.316283            1363.317251
#
#        E2E Delay (s)     model_acc
# count    1000.000000  1.000000e+03
# mean        0.877218  6.410000e+01
# std         0.157000  1.421797e-14
# min         0.611672  6.410000e+01
# 25%         0.763658  6.410000e+01
# 50%         0.868806  6.410000e+01
# 75%         0.942997  6.410000e+01
# max         2.107741  6.410000e+01

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, nrows=1, figsize=(16,5))

ax1.plot(df_med_half.index[0:1000], df_med_half['Processing Delay (ms)'][0:1000]/1000, label= 'Half Core - Med')
ax1.plot(df_med_one.index[0:1000], df_med_one['Processing Delay (ms)'][0:1000]/1000, label='One Core - Med')
ax1.plot(df_med_two.index[0:1000], df_med_two['Processing Delay (ms)'][0:1000]/1000, label = 'Two Core - Med')
ax1.set_title('Processing Delay')
ax1.set_xlabel('Number of Requests')
ax1.set_ylabel('Delay (ms)')
ax1.grid(True)


ax2.plot(df_med_half.index[0:500], df_med_half['E2E Delay (s)'][0:500], label= 'Half Core - Med')
ax2.plot(df_med_one.index[0:500], df_med_one['E2E Delay (s)'][0:500], label='One Core - Med')
ax2.plot(df_med_two.index[0:500], df_med_two['E2E Delay (s)'][0:500], label = 'Two Core - Med')
ax2.set_title('Processing Delay')
ax2.set_xlabel('Number of Requests')
ax2.set_ylabel('Delay (ms)')
ax2.grid(True)

plt.legend()
plt.show()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(16,16))

ax1.plot(df_nano_half.index[0:1000], df_nano_half['Processing Delay (ms)'][0:1000]/1000, label= 'Nano - 45.7')
ax1.plot(df_small_half.index[0:1000], df_small_half['Processing Delay (ms)'][0:1000]/1000, label='Small - 56.8')
ax1.plot(df_med_half.index[0:1000], df_med_half['Processing Delay (ms)'][0:1000]/1000, label = 'Medium - 64.1')
ax1.set_title('Half Core')
ax1.set_xlabel('Number of Requests')
ax1.set_ylabel('Delay (s)')
ax1.grid(True)
ax1.legend()

ax2.plot(df_nano_one.index[0:1000], df_nano_one['Processing Delay (ms)'][0:1000]/1000, label= 'Nano - 45.7')
ax2.plot(df_small_one.index[0:1000], df_small_one['Processing Delay (ms)'][0:1000]/1000, label='Small - 56.8')
ax2.plot(df_med_one.index[0:1000], df_med_one['Processing Delay (ms)'][0:1000]/1000, label = 'Medium - 64.1')
ax2.set_title('One Core')
ax2.set_xlabel('Number of Requests')
ax2.set_ylabel('Delay (s)')
ax2.grid(True)
ax2.legend()

ax3.plot(df_nano_two.index[0:1000], df_nano_two['Processing Delay (ms)'][0:1000]/1000, label= 'Nano - 45.7')
ax3.plot(df_small_two.index[0:1000], df_small_two['Processing Delay (ms)'][0:1000]/1000, label='Small - 56.8')
ax3.plot(df_med_two.index[0:1000], df_med_two['Processing Delay (ms)'][0:1000]/1000, label = 'Medium - 64.1')
ax3.set_title('Two Core')
ax3.set_xlabel('Number of Requests')
ax3.set_ylabel('Delay (s)')
ax3.grid(True)
ax3.legend()
plt.savefig('version_comparison.pdf', format='pdf')
plt.show()

# %%
df_client[df_client['E2E Delay (s)']>1].count()
# Out:
# Time                     254
# Model Name               254
# File Name                254
# Propagation Delay (s)    254
# Processing Delay (ms)    254
# E2E Delay (s)            254
# dtype: int64

# %%
df_client['E2E Delay (s)'].count()
# Out:
# 404

# %%
sla_violation_rate = (df_client[df_client['E2E Delay (s)']>1].count())/df_client['E2E Delay (s)'].count()
sla_violation_rate
# Out:
# Time                     0.628713
# Model Name               0.628713
# File Name                0.628713
# Propagation Delay (s)    0.628713
# Processing Delay (ms)    0.628713
# E2E Delay (s)            0.628713
# dtype: float64

# %%
df_client_new = pd.read_csv('client_stats_sla.csv')
df_client_new.head()
# Out:
#            Time Model Name File Name  Propagation Delay (s)  \
# 0  1.713484e+09    yolov5n     6.jpg               0.703823
# 1  1.713484e+09    yolov5n     6.jpg               0.582535
# 2  1.713484e+09    yolov5n     6.jpg               0.481447
# 3  1.713484e+09    yolov5n     6.jpg               0.548160
# 4  1.713484e+09    yolov5n     6.jpg               0.800635
#
#    Processing Delay (ms)  E2E Delay (s)      location  core
# 0             453.441381       1.180513  europe-west9   500
# 1             560.755491       1.188192  europe-west9   500
# 2             226.257324       0.731383  europe-west9  1000
# 3             263.905048       0.855502  europe-west9  1000
# 4             372.334242       1.194916  europe-west9  1000

# %%
df_client_new.tail()
# Out:
#              Time Model Name File Name  Propagation Delay (s)  \
# 197  1.713484e+09    yolov5n     6.jpg               0.616490
# 198  1.713484e+09    yolov5n     6.jpg               0.721834
# 199  1.713484e+09    yolov5n     6.jpg               0.627959
# 200  1.713484e+09    yolov5n     6.jpg               0.627808
# 201  1.713484e+09    yolov5n     6.jpg               0.709380
#
#      Processing Delay (ms)  E2E Delay (s)      location  core
# 197             338.721991       1.010873  europe-west9  1000
# 198             181.076050       0.926919  europe-west9  1000
# 199             156.996012       0.831082  europe-west9  1000
# 200             368.720770       1.019890  europe-west9  1000
# 201             351.717472       1.108409  europe-west9  1000

# %%
df_client_new[df_client_new['E2E Delay (s)'] > 1].count()/ df_client_new['E2E Delay (s)'].count()
# Out:
# Time                     0.316832
# Model Name               0.316832
# File Name                0.316832
# Propagation Delay (s)    0.316832
# Processing Delay (ms)    0.316832
# E2E Delay (s)            0.316832
# location                 0.316832
# core                     0.316832
# dtype: float64

# %%
plt.figure(figsize=(10,4))
plt.plot(df_client_new.index, df_client_new['E2E Delay (s)'], label='E2E Delay (s) ')
plt.title('E2E Delay')
plt.xlabel('Number of Requests')
plt.ylabel('Delay (s)')
plt.legend()
plt.grid(True)
plt.ylim([0,1.5])
plt.show()

# %% [markdown]
# ##  Four Containers Analysis

# %%
column_names = ['Time',	'Model Name', 'File Name', 'Propagation Delay (s)', 'Processing Delay (ms)', 'E2E Delay (s)', 'location', 'core']
#df4_prokube = pd.read_csv('four_containers/ClientStat_1713523707.3637729.csv', header=None, names=column_names)

# %%
df4_prokube = pd.read_csv('four_containers/ClientStat_1713523707.3637729.csv', header=None, names=column_names)
df4_costgreedy = pd.read_csv('four_containers/ClientStat_1714057800.8877995_CostGreedy.csv', header=None, names=column_names)
df4_latencygreedy = pd.read_csv('four_containers/ClientStat_1714063588.640397_LatencyGreedy.csv', header=None, names=column_names)

# %%
print(f'ProKube: {df4_prokube.shape}, Cost: {df4_costgreedy.shape}, Latency: {df4_latencygreedy.shape}')
# Out:
# ProKube: (404, 8), Cost: (404, 8), Latency: (404, 8)

# %%
df_four_original = df4_prokube
df4_prokube = df4_prokube[df4_prokube['E2E Delay (s)']<2]
print(df4_prokube.shape, df_four_original.shape)
# Out:
# (402, 8) (404, 8)

# %%
plt.figure(figsize=(10,4))
plt.plot(df4_prokube.index, df4_prokube['E2E Delay (s)'], label='ProKube')
plt.plot(df4_costgreedy.index, df4_costgreedy['E2E Delay (s)'], label='Cost Greedy')
plt.plot(df4_latencygreedy.index, df4_latencygreedy['E2E Delay (s)'], label='Latency Greedy')
plt.title('E2E Delay')
plt.xlabel('Number of Requests')
plt.ylabel('Delay (s)')
plt.legend()
plt.grid(True)
plt.ylim([0,2.5])
plt.show()

# %%
df_four = df_four_original

# %%
sla4_prokube = df4_prokube[df4_prokube['E2E Delay (s)'] > 1].count()/ df4_prokube['E2E Delay (s)'].count()
sla4_cost = df4_costgreedy[df4_costgreedy['E2E Delay (s)'] > 1].count()/ df4_costgreedy['E2E Delay (s)'].count()
sla4_latency = df4_latencygreedy[df4_latencygreedy['E2E Delay (s)'] > 1].count()/ df4_latencygreedy['E2E Delay (s)'].count()
print(f'Pro-SLA: {sla4_prokube}, Cost-SLA: {sla4_cost}, Latency-SLA: {sla4_latency}')
# Out:
# Pro-SLA: Time                     0.208955
# Model Name               0.208955
# File Name                0.208955
# Propagation Delay (s)    0.208955
# Processing Delay (ms)    0.208955
# E2E Delay (s)            0.208955
# location                 0.208955
# core                     0.208955
# dtype: float64, Cost-SLA: Time                     0.846535
# Model Name               0.846535
# File Name                0.846535
# Propagation Delay (s)    0.846535
# Processing Delay (ms)    0.846535
# E2E Delay (s)            0.846535
# location                 0.846535
# core                     0.846535
# dtype: float64, Latency-SLA: Time                     0.133663
# Model Name               0.133663
# File Name                0.133663
# Propagation Delay (s)    0.133663
# Processing Delay (ms)    0.133663
# E2E Delay (s)            0.133663
# location                 0.133663
# core                     0.133663
# dtype: float64

# %%
sla4_prokube_half = df4_prokube[(df4_prokube['E2E Delay (s)'] > 1 ) & (df4_prokube['core'] == 500 )].count()/ df4_prokube[df4_prokube['core'] == 500].count()
sla4_cost_half = df4_costgreedy[(df4_costgreedy['E2E Delay (s)'] > 1 ) & (df4_costgreedy['core'] == 500 )].count()/ df4_costgreedy[df4_costgreedy['core'] == 500].count()
print(f'Pro-SLA-Half: {sla4_prokube_half}, Cost-SLA-Half: {sla4_cost_half}')
# Out:
# Pro-SLA-Half: Time                     0.723404
# Model Name               0.723404
# File Name                0.723404
# Propagation Delay (s)    0.723404
# Processing Delay (ms)    0.723404
# E2E Delay (s)            0.723404
# location                 0.723404
# core                     0.723404
# dtype: float64, Cost-SLA-Half: Time                     0.846535
# Model Name               0.846535
# File Name                0.846535
# Propagation Delay (s)    0.846535
# Processing Delay (ms)    0.846535
# E2E Delay (s)            0.846535
# location                 0.846535
# core                     0.846535
# dtype: float64

# %%
df4_costgreedy[df4_costgreedy['core'] == 500].count()
# Out:
# Time                     404
# Model Name               404
# File Name                404
# Propagation Delay (s)    404
# Processing Delay (ms)    404
# E2E Delay (s)            404
# location                 404
# core                     404
# dtype: int64

# %%
sla_vio_rate_four_one = df4_costgreedy[(df4_costgreedy['E2E Delay (s)'] > 1 ) & (df4_costgreedy['core'] == 1000 )].count()/ df4_costgreedy[df4_costgreedy['core'] == 1000].count()
sla_vio_rate_four_one
# Out:
# Time                    NaN
# Model Name              NaN
# File Name               NaN
# Propagation Delay (s)   NaN
# Processing Delay (ms)   NaN
# E2E Delay (s)           NaN
# location                NaN
# core                    NaN
# dtype: float64

# %%
sla_vio_rate_four_two = df_four[(df_four['E2E Delay (s)'] > 1 ) & (df_four['core'] == 2000 )].count()/ df_four[df_four['core'] == 2000].count()
sla_vio_rate_four_two
# Out:
# Time                    NaN
# Model Name              NaN
# File Name               NaN
# Propagation Delay (s)   NaN
# Processing Delay (ms)   NaN
# E2E Delay (s)           NaN
# location                NaN
# core                    NaN
# dtype: float64

# %%
df_four[df_four['core'] == 1000].count()
# Out:
# Time                     357
# Model Name               357
# File Name                357
# Propagation Delay (s)    357
# Processing Delay (ms)    357
# E2E Delay (s)            357
# location                 357
# core                     357
# dtype: int64

# %%
df_four[df_four['E2E Delay (s)'] > 1].count()
# Out:
# Time                     86
# Model Name               86
# File Name                86
# Propagation Delay (s)    86
# Processing Delay (ms)    86
# E2E Delay (s)            86
# location                 86
# core                     86
# dtype: int64

# %%
df_four['E2E Delay (s)'].count()
# Out:
# 404

# %%
server_columns = ['migrations', 'scalings', 'cost']

# %%
df4_prokube_server = pd.read_csv('four_containers/ServerStat_1713523707.3637729.csv', header=None, names=server_columns)
df4_cost_server = pd.read_csv('four_containers/ServerStat_1714057800.8877995_CostGreedy.csv', header=None, names=server_columns)
df4_latency_server = pd.read_csv('four_containers/ServerStat_1714063588.640397_LatencyGreedy.csv', header=None, names=server_columns)

print(f'Pro-Server: {df4_prokube_server.shape}, Cost-Serevr: {df4_cost_server.shape}, Latency-Server: {df4_latency_server.shape}')
# Out:
# Pro-Server: (101, 3), Cost-Serevr: (101, 3), Latency-Server: (101, 3)

# %%
pro4_migrations = round(df4_prokube_server['migrations'].sum()/df4_prokube_server['migrations'].count(),ndigits=2)
cost4_migrations = round(df4_cost_server['migrations'].sum()/df4_cost_server['migrations'].count(),ndigits=2)
latency4_migrations = round(df4_latency_server['migrations'].sum()/df4_latency_server['migrations'].count(),ndigits=2)

print(f'Pro-Migrations: {pro4_migrations}, Cost-Migrations: {cost4_migrations}, Latency-Migrations: {latency4_migrations}')
# Out:
# Pro-Migrations: 0.03, Cost-Migrations: 0.0, Latency-Migrations: 0.37

# %%
pro4_scalings = round(df4_prokube_server['scalings'].sum()/df4_prokube_server['scalings'].count(),ndigits=2)
cost4_scalings = round(df4_cost_server['scalings'].sum()/df4_cost_server['scalings'].count(),ndigits=2)
latency4_scalings = round(df4_latency_server['scalings'].sum()/df4_latency_server['scalings'].count(),ndigits=2)

print(f'Pro-Scalings: {pro4_scalings}, Cost-Scalings: {cost4_scalings}, Latency-Scalings: {latency4_scalings}')
# Out:
# Pro-Scalings: 0.04, Cost-Scalings: 0.0, Latency-Scalings: 0.04

# %%
pro4_cost = round(df4_prokube_server['cost'].sum()/df4_prokube_server['cost'].count(),ndigits=2)
cost4_cost = round(df4_cost_server['cost'].sum()/df4_cost_server['cost'].count(),ndigits=2)
latency4_cost = round(df4_latency_server['cost'].sum()/df4_latency_server['cost'].count(),ndigits=2)
print(f'Pro-Cost: {pro4_cost}, Cost-Cost: {cost4_cost}, Latency-Cost: {latency4_cost}')
# Out:
# Pro-Cost: 3.77, Cost-Cost: 2.0, Latency-Cost: 7.94

# %%
plt.figure(figsize=(10,4))
plt.plot(df4_prokube_server.index, df4_prokube_server['migrations'], label='ProKube Migrations')
plt.plot(df4_cost_server.index, df4_cost_server['migrations'], label='Cost Migrations')
plt.plot(df4_latency_server.index, df4_latency_server['migrations'], label='Latency Migrations')
plt.title('E2E Delay')
plt.xlabel('Number of Requests')
plt.ylabel('Migrations Count')
plt.legend()
plt.grid(True)
#plt.ylim([0,2])
plt.show()

# %%
df_four_server['scalings'].sum()/df_four_server['scalings'].count()
# Out:
# 0.039603960396039604

# %%
plt.figure(figsize=(10,4))
plt.plot(df4_prokube_server.index, df4_prokube_server['scalings'], label='ProKube Scaling')
plt.plot(df4_cost_server.index, df4_cost_server['scalings'], label='Cost Scaling')
plt.plot(df4_latency_server.index, df4_latency_server['scalings'], label='Latency Scaling')

plt.title('E2E Delay')
plt.xlabel('Number of Requests')
plt.ylabel('Scaling Count')
plt.legend()
plt.grid(True)
#plt.ylim([0,2])
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.plot(df4_prokube_server.index, df4_prokube_server['cost'], label='ProKube Cost')
plt.plot(df4_cost_server.index, df4_cost_server['cost'], label='Cost Greedy Cost')
plt.plot(df4_latency_server.index, df4_latency_server['cost'], label='Latency Greedy Cost')
plt.title('Cost')
plt.xlabel('Number of Requests')
plt.ylabel('Cost')
plt.legend()
plt.grid(True)
plt.ylim([0,10])
plt.show()

# %%
df_four_server['cost'].sum()/df_four_server['cost'].count()
# Out:
# 3.767326732673267

# %% [markdown]
# ## Eight Containers P99

# %%
column_names = ['Time',	'Model Name', 'File Name', 'Propagation Delay (s)', 'Processing Delay (ms)', 'E2E Delay (s)', 'location', 'core']

# Read the CSV file with specified column names
df_eight_p99 = pd.read_csv('ClientStat_1713528274.3323467.csv', header=None, names=column_names)
df_eight_p99.head()
# Out:
#            Time Model Name File Name  Propagation Delay (s)  \
# 0  1.713529e+09    yolov5n     6.jpg               0.426231
# 1  1.713529e+09    yolov5n     6.jpg               0.577721
# 2  1.713529e+09    yolov5n     6.jpg               0.451056
# 3  1.713529e+09    yolov5n     6.jpg               0.630036
# 4  1.713529e+09    yolov5n     6.jpg               0.808032
#
#    Processing Delay (ms)  E2E Delay (s)      location  core
# 0             869.368792       1.352022  europe-west3   500
# 1             525.316954       1.127793  europe-west1   500
# 2             801.656961       1.293375  europe-west2   500
# 3             429.790735       1.080420  europe-west9   500
# 4             622.407436       1.474563  europe-west3   500

# %%
df_eight_p99.shape
# Out:
# (652, 8)

# %%
plt.figure(figsize=(10,4))
plt.plot(df_eight_p99.index, df_eight_p99['E2E Delay (s)'], label='E2E Delay (s) ')
plt.title('E2E Delay')
plt.xlabel('Number of Requests')
plt.ylabel('Delay (s)')
plt.legend()
plt.grid(True)
#plt.ylim([0,2])
plt.show()

# %%
df_eight_p99[df_eight_p99['E2E Delay (s)'] > 1].count()/ df_eight_p99['E2E Delay (s)'].count()
# Out:
# Time                     0.52454
# Model Name               0.52454
# File Name                0.52454
# Propagation Delay (s)    0.52454
# Processing Delay (ms)    0.52454
# E2E Delay (s)            0.52454
# location                 0.52454
# core                     0.52454
# dtype: float64

# %%
df_eight_p99[df_eight_p99['E2E Delay (s)'] > 1].count()
# Out:
# Time                     342
# Model Name               342
# File Name                342
# Propagation Delay (s)    342
# Processing Delay (ms)    342
# E2E Delay (s)            342
# location                 342
# core                     342
# dtype: int64

# %%
server_columns = ['migrations', 'scalings', 'cost']
df_eight_server_p99 = pd.read_csv('ServerStat_1713528274.3323467.csv', header=None, names=server_columns)
df_eight_server_p99
# Out:
#     migrations  scalings  cost
# 0            0         0   4.0
# 1            1         1   5.5
# 2            0         0   5.5
# 3            0         0   5.5
# 4            0         0   5.5
# ..         ...       ...   ...
# 76           0         0  10.0
# 77           0         0  10.0
# 78           0         0  10.0
# 79           0         0  10.0
# 80           0         0  10.0
#
# [81 rows x 3 columns]

# %%
df_eight_server_p99['migrations'].sum()/df_eight_server_p99['migrations'].count()
# Out:
# 0.06172839506172839

# %%
df_eight_server_p99['scalings'].sum()/df_eight_server_p99['scalings'].count()
# Out:
# 0.04938271604938271

# %%
df_eight_server_p99['cost'].sum()/df_eight_server_p99['cost'].count()
# Out:
# 8.777777777777779

# %% [markdown]
# ## Eight Container P75 Analysis

# %%
#column_names = ['Time',	'Model Name', 'File Name', 'Propagation Delay (s)', 'Processing Delay (ms)', 'E2E Delay (s)', 'location', 'core']

df8_prokube = pd.read_csv('eight_containers_75/ClientStat_1713524976.4174697.csv', header=None, names=column_names)
df8_costgreedy = pd.read_csv('eight_containers_75/ClientStat_1714059688.0958374_CostGreedy.csv', header=None, names=column_names)
df8_latencygreedy = pd.read_csv('eight_containers_75/ClientStat_1714070506.0299976_LatencyGreedy.csv', header=None, names=column_names)

print(f'Prokube: {df8_prokube.shape}, Cost: {df8_costgreedy.shape}, Latency: {df8_latencygreedy.shape}')
# Out:
# Prokube: (808, 8), Cost: (808, 8), Latency: (808, 8)

# %%
df_original = df8_prokube
df8_prokube = df8_prokube[df8_prokube['Propagation Delay (s)'] < 2]

# %%
plt.figure(figsize=(10,4))
plt.plot(df8_prokube.index, df8_prokube['E2E Delay (s)'], label='E2E Delay Four Containers')
plt.plot(df8_costgreedy.index, df8_costgreedy['E2E Delay (s)'], label='E2E Delay Eight Containers')
plt.plot(df8_latencygreedy.index, df8_latencygreedy['E2E Delay (s)'], label='E2E Delay Eight Containers')
plt.title('E2E Delay')
plt.xlabel('Number of Requests')
plt.ylabel('Delay (s)')
plt.legend()
plt.grid(True)
plt.axhline(y=1, color='g', linestyle='--', label='Target Delay')
plt.ylim([0,3])
plt.savefig('e2e_delay.pdf', format='pdf')
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.plot(df8_prokube.index, df8_prokube['Propagation Delay (s)'], label='ProKube - Propagation Delay')
plt.plot(df8_costgreedy.index, df8_costgreedy['Propagation Delay (s)'], label='Cost Greedy - Propagation Delay')
plt.plot(df8_latencygreedy.index, df8_latencygreedy['Propagation Delay (s)'], label='Latency Greedy - Propagation Delay')
plt.title('Propagation Delay')
plt.xlabel('Number of Requests')
plt.ylabel('Propagation Delay (s)')
plt.legend()
plt.grid(True)
plt.axhline(y=1, color='g', linestyle='--', label='Target Delay')
#plt.ylim([0,2])
plt.show()

plt.figure(figsize=(10,4))

# %%
plt.figure(figsize=(10,5))
plt.plot(df8_prokube.index, df8_prokube['Processing Delay (ms)']/1000, label='ProKube - Processing Delay')
plt.plot(df8_costgreedy.index, df8_costgreedy['Processing Delay (ms)']/1000, label='Cost Greedy - Processing Delay')
plt.plot(df8_latencygreedy.index, df8_latencygreedy['Processing Delay (ms)']/1000, label='Latency Greedy - Processing Delay')
plt.title('Processing Delay')
plt.xlabel('Number of Requests')
plt.ylabel('Processing Delay (s)')
plt.legend()
plt.grid(True)
plt.axhline(y=1, color='g', linestyle='--', label='Target Delay')
#plt.ylim([0,2])
plt.show()

plt.figure(figsize=(10,4))

# %%
plt.figure(figsize=(6,4))

plt.plot(df4_prokube.index, df4_prokube['Processing Delay (ms)']/1000, label='PK - Processing Delay')
plt.plot(df4_costgreedy.index, df4_costgreedy['Processing Delay (ms)']/1000, label='CG - Processing Delay')
plt.plot(df4_latencygreedy.index, df4_latencygreedy['Processing Delay (ms)']/1000, label='LG - Processing Delay')
plt.ylabel('Processing Delay (s)')
plt.xlabel('Number of Requests')
plt.grid(True)
plt.axhline(y=1, color='g', linestyle='--', label='Target Delay')
plt.ylim([0,3])
#plt.title('Four Contianer Processing Delay')
plt.savefig('processing_four.pdf', format='pdf')
plt.legend(loc='upper right')

# %%
plt.figure(figsize=(6,4))
plt.plot(df8_prokube.index, df8_prokube['Processing Delay (ms)']/1000, label='PK - Processing Delay')
plt.plot(df8_costgreedy.index, df8_costgreedy['Processing Delay (ms)']/1000, label='CG - Processing Delay')
plt.plot(df8_latencygreedy.index, df8_latencygreedy['Processing Delay (ms)']/1000, label='LG - Processing Delay')
plt.ylabel('Processing Delay (s)')
plt.xlabel('Number of Requests')
plt.grid(True)
plt.axhline(y=1, color='g', linestyle='--', label='Target Delay')
plt.ylim([0,3])
#plt.title('Eight Contianer Processing Delay')
plt.savefig('processing_eight.pdf', format='pdf')
plt.legend(loc='upper right')

# %%
# Subplot 2: Propagation Delay
plt.figure(figsize=(6,4))
plt.plot(df4_prokube.index, df4_prokube['Propagation Delay (s)'], label='PK - Propagation Delay')
plt.plot(df4_costgreedy.index, df4_costgreedy['Propagation Delay (s)'], label='CG - Propagation Delay')
plt.plot(df4_latencygreedy.index, df4_latencygreedy['Propagation Delay (s)'], label='LG - Propagation Delay')
plt.ylabel('Propagation Delay (s)')
plt.xlabel('Number of Requests')
#ax2.set_ylim([0,20])
plt.grid(True)
plt.axhline(y=1, color='g', linestyle='--', label='Target Delay')
plt.ylim([0,3])
plt.savefig('propagation_four.pdf', format='pdf')
plt.legend(loc='upper right')

# %%
plt.figure(figsize=(6,4))
plt.plot(df8_prokube.index, df8_prokube['Propagation Delay (s)'], label='PK - Propagation Delay')
plt.plot(df8_costgreedy.index, df8_costgreedy['Propagation Delay (s)'], label='CG - Propagation Delay')
plt.plot(df8_latencygreedy.index, df8_latencygreedy['Propagation Delay (s)'], label='LG - Propagation Delay')
plt.ylabel('Propagation Delay (s)')
plt.xlabel('Number of Requests')
#ax2.set_ylim([0,20])
plt.grid(True)
plt.axhline(y=1, color='g', linestyle='--', label='Target Delay')
plt.ylim([0,3])
plt.savefig('propagation_eight.pdf', format='pdf')
plt.legend(loc='upper right')

# %%
plt.figure(figsize=(6,4))
plt.plot(df4_prokube.index, df4_prokube['E2E Delay (s)'], label='PK - E2E Delay')
plt.plot(df4_costgreedy.index, df4_costgreedy['E2E Delay (s)'], label='CG - E2E Delay')
plt.plot(df4_latencygreedy.index, df4_latencygreedy['E2E Delay (s)'], label='LG - E2E Delay')
plt.ylabel('E2E Delay (s)')
plt.xlabel('Number of Requests')
#ax2.set_ylim([0,20])
plt.grid(True)
plt.axhline(y=1, color='g', linestyle='--', label='Target Delay')
plt.ylim([0,3])
plt.savefig('e2e_four.pdf', format='pdf')
plt.legend(loc='upper right')

# %%
plt.figure(figsize=(6,4))
plt.plot(df8_prokube.index, df8_prokube['E2E Delay (s)'], label='PK - E2E Delay')
plt.plot(df8_costgreedy.index, df8_costgreedy['E2E Delay (s)'], label='CG - E2E Delay')
plt.plot(df8_latencygreedy.index, df8_latencygreedy['E2E Delay (s)'], label='LG - E2E Delay')
plt.ylabel('E2E Delay (s)')
plt.xlabel('Number of Requests')
#ax2.set_ylim([0,20])
plt.grid(True)
plt.axhline(y=1, color='g', linestyle='--', label='Target Delay')
plt.ylim([0,3])
plt.savefig('e2e_eight.pdf', format='pdf')
plt.legend(loc='upper right')

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(2, 3, figsize=(16, 8))

#ax1.plot(inf_time5.index, inf_time5, label='Inference Time 500m', marker='o')
#ax1.plot(inf_time1.index, inf_time1, label='Inference Time 1 Core', marker='o')
#ax1.plot(proc_time5.index, proc_time5, marker='o', label='500m Core')

# Processing Delay
ax1.plot(df4_prokube.index, df4_prokube['Processing Delay (ms)']/1000, label='PK - Processing Delay')
ax1.plot(df4_costgreedy.index, df4_costgreedy['Processing Delay (ms)']/1000, label='CG - Processing Delay')
ax1.plot(df4_latencygreedy.index, df4_latencygreedy['Processing Delay (ms)']/1000, label='LG - Processing Delay')
ax1.set_ylabel('Processing Delay (s)')
ax1.set_xlabel('Number of Requests')
ax1.grid(True)
ax1.axhline(y=1, color='g', linestyle='--', label='Target Delay')
ax1.set_ylim([0,3])
ax1.set_title('Four Contianer Processing Delay')
ax1.legend(loc='upper right')

ax4.plot(df8_prokube.index, df8_prokube['Processing Delay (ms)']/1000, label='PK - Processing Delay')
ax4.plot(df8_costgreedy.index, df8_costgreedy['Processing Delay (ms)']/1000, label='CG - Processing Delay')
ax4.plot(df8_latencygreedy.index, df8_latencygreedy['Processing Delay (ms)']/1000, label='LG - Processing Delay')
ax4.set_ylabel('Processing Delay (s)')
ax4.set_xlabel('Number of Requests')
ax4.grid(True)
ax4.axhline(y=1, color='g', linestyle='--', label='Target Delay')
ax4.set_ylim([0,3])
ax4.set_title('Eight Contianer Processing Delay')
ax4.legend(loc='upper right')

# Subplot 2: Propagation Delay
ax2.plot(df4_prokube.index, df4_prokube['Propagation Delay (s)'], label='PK - Propagation Delay')
ax2.plot(df4_costgreedy.index, df4_costgreedy['Propagation Delay (s)'], label='CG - Propagation Delay')
ax2.plot(df4_latencygreedy.index, df4_latencygreedy['Propagation Delay (s)'], label='LG - Propagation Delay')
ax2.set_ylabel('Propagation Delay (s)')
ax2.set_xlabel('Number of Requests')
#ax2.set_ylim([0,20])
ax2.grid(True)
ax2.axhline(y=1, color='g', linestyle='--', label='Target Delay')
ax2.set_ylim([0,3])
ax2.set_title('Four Contianer Propagation Delay')
ax2.legend(loc='upper right')

ax5.plot(df8_prokube.index, df8_prokube['Propagation Delay (s)'], label='PK - Propagation Delay')
ax5.plot(df8_costgreedy.index, df8_costgreedy['Propagation Delay (s)'], label='CG - Propagation Delay')
ax5.plot(df8_latencygreedy.index, df8_latencygreedy['Propagation Delay (s)'], label='LG - Propagation Delay')
ax5.set_ylabel('Propagation Delay (s)')
ax5.set_xlabel('Number of Requests')
#ax2.set_ylim([0,20])
ax5.grid(True)
ax5.axhline(y=1, color='g', linestyle='--', label='Target Delay')
ax5.set_ylim([0,3])
ax5.set_title('Eight Contianer Propagation Delay')
ax5.legend(loc='upper right')

# Subplot 2: E2E Delay
ax3.plot(df4_prokube.index, df4_prokube['E2E Delay (s)'], label='PK - E2E Delay')
ax3.plot(df4_costgreedy.index, df4_costgreedy['E2E Delay (s)'], label='CG - E2E Delay')
ax3.plot(df4_latencygreedy.index, df4_latencygreedy['E2E Delay (s)'], label='LG - E2E Delay')
ax3.set_ylabel('E2E Delay (s)')
ax3.set_xlabel('Number of Requests')
#ax2.set_ylim([0,20])
ax3.grid(True)
ax3.axhline(y=1, color='g', linestyle='--', label='Target Delay')
ax3.set_ylim([0,3])
ax3.set_title('Four Contianer E2E Delay')
ax3.legend(loc='upper right')

ax6.plot(df8_prokube.index, df8_prokube['E2E Delay (s)'], label='PK - E2E Delay')
ax6.plot(df8_costgreedy.index, df8_costgreedy['E2E Delay (s)'], label='CG - E2E Delay')
ax6.plot(df8_latencygreedy.index, df8_latencygreedy['E2E Delay (s)'], label='LG - E2E Delay')
ax6.set_ylabel('E2E Delay (s)')
ax6.set_xlabel('Number of Requests')
#ax2.set_ylim([0,20])
ax6.grid(True)
ax6.axhline(y=1, color='g', linestyle='--', label='Target Delay')
ax6.set_ylim([0,3])
ax6.set_title('Eigth Contianer E2E Delay')
ax6.legend(loc='upper right')

plt.subplots_adjust(wspace=0.3)
#plt.suptitle('Delays for Four and Eight Containers')

# Adjust layout
plt.tight_layout()
# Show plot
plt.savefig('delays.pdf', format='pdf')
plt.show()

# %%
sla_violation_rate_four
# Out:
# Time                     0.208955
# Model Name               0.208955
# File Name                0.208955
# Propagation Delay (s)    0.208955
# Processing Delay (ms)    0.208955
# E2E Delay (s)            0.208955
# location                 0.208955
# core                     0.208955
# dtype: float64

# %%
#df_four[df_four['E2E Delay (s)'] > 1].count()/ df_four['E2E Delay (s)'].count()

sla_violation_rate_eight = df_eight_p75[df_eight_p75['E2E Delay (s)']>1].count()/df_eight_p75['E2E Delay (s)'].count()
sla_violation_rate_eight
# Out:
# Time                     0.194307
# Model Name               0.194307
# File Name                0.194307
# Propagation Delay (s)    0.194307
# Processing Delay (ms)    0.194307
# E2E Delay (s)            0.194307
# location                 0.194307
# core                     0.194307
# dtype: float64

# %%
sla_vio_rate_eight_half = df_eight_p75[(df_eight_p75['E2E Delay (s)'] > 1 ) & (df_eight_p75['core'] == 500 )].count()/ df_eight_p75[df_eight_p75['core'] == 500].count()
sla_vio_rate_eight_half
# Out:
# Time                     1.0
# Model Name               1.0
# File Name                1.0
# Propagation Delay (s)    1.0
# Processing Delay (ms)    1.0
# E2E Delay (s)            1.0
# location                 1.0
# core                     1.0
# dtype: float64

# %%
sla_vio_rate_eight_one = df_eight_p75[(df_eight_p75['E2E Delay (s)'] > 1 ) & (df_eight_p75['core'] == 1000 )].count()/ df_eight_p75[df_eight_p75['core'] == 1000].count()
sla_vio_rate_eight_one
# Out:
# Time                     0.17803
# Model Name               0.17803
# File Name                0.17803
# Propagation Delay (s)    0.17803
# Processing Delay (ms)    0.17803
# E2E Delay (s)            0.17803
# location                 0.17803
# core                     0.17803
# dtype: float64

# %%
sla_vio_rate_eight_two = df_eight_p75[(df_eight_p75['E2E Delay (s)'] > 1 ) & (df_eight_p75['core'] == 2000 )].count()/ df_eight_p75[df_eight_p75['core'] == 2000].count()
sla_vio_rate_eight_two
# Out:
# Time                    NaN
# Model Name              NaN
# File Name               NaN
# Propagation Delay (s)   NaN
# Processing Delay (ms)   NaN
# E2E Delay (s)           NaN
# location                NaN
# core                    NaN
# dtype: float64

# %%
# Sample data (replace with your actual data)
containers = ['Four Containers', 'Eight Containers']
cores = ['Overall SLA', 'Two Core', 'One Core', 'Half Core']

# Overall SLA violation rates for different container configurations
overall_sla_rates = {
    'Four Containers': [sla_violation_rate_four[0], 0, sla_vio_rate_four_one[0], sla_vio_rate_four_half[0]],  # Replace with actual values
    'Eight Containers': [sla_violation_rate_eight[0], 0, sla_vio_rate_eight_one[0], sla_vio_rate_eight_half[0]]   # Replace with actual values
}

# Plotting
fig, ax = plt.subplots(figsize=(7, 4))

bar_width = 0.4
index = np.arange(len(cores))

# Plot bars for 4 Containers
bar1 = ax.bar(index, overall_sla_rates['Four Containers'], bar_width, label='SLA - Four')

# Plot bars for 8 Containers
bar2 = ax.bar(index + bar_width, overall_sla_rates['Eight Containers'], bar_width, label='SLA - Eight')

ax.set_xlabel('Container Cores')
ax.set_ylabel('SLA Violation Rate')
#ax.set_title('SLA Violation Rates for Four and Eight Containers')
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(cores)
ax.legend()

plt.tight_layout()
plt.savefig('sla_violation.pdf', format='pdf')
plt.show()

# %%
sla4_cost
# Out:
# Time                     0.846535
# Model Name               0.846535
# File Name                0.846535
# Propagation Delay (s)    0.846535
# Processing Delay (ms)    0.846535
# E2E Delay (s)            0.846535
# location                 0.846535
# core                     0.846535
# dtype: float64

# %%
sla4_latency
# Out:
# Time                     0.133663
# Model Name               0.133663
# File Name                0.133663
# Propagation Delay (s)    0.133663
# Processing Delay (ms)    0.133663
# E2E Delay (s)            0.133663
# location                 0.133663
# core                     0.133663
# dtype: float64

# %%
sla4_prokube
# Out:
# Time                     0.208955
# Model Name               0.208955
# File Name                0.208955
# Propagation Delay (s)    0.208955
# Processing Delay (ms)    0.208955
# E2E Delay (s)            0.208955
# location                 0.208955
# core                     0.208955
# dtype: float64

# %%
sla4_prokube = df4_prokube[df4_prokube['E2E Delay (s)'] > 1].count()/ df4_prokube['E2E Delay (s)'].count()
sla4_cost = df4_costgreedy[df4_costgreedy['E2E Delay (s)'] > 1].count()/ df4_costgreedy['E2E Delay (s)'].count()
sla4_latency = df4_latencygreedy[df4_latencygreedy['E2E Delay (s)'] > 1].count()/ df4_latencygreedy['E2E Delay (s)'].count()
print(f'Pro-SLA: {sla4_prokube}, Cost-SLA: {sla4_cost}, Latency-SLA: {sla4_latency}')
# Out:
# Pro-SLA: Time                     0.208955
# Model Name               0.208955
# File Name                0.208955
# Propagation Delay (s)    0.208955
# Processing Delay (ms)    0.208955
# E2E Delay (s)            0.208955
# location                 0.208955
# core                     0.208955
# dtype: float64, Cost-SLA: Time                     0.846535
# Model Name               0.846535
# File Name                0.846535
# Propagation Delay (s)    0.846535
# Processing Delay (ms)    0.846535
# E2E Delay (s)            0.846535
# location                 0.846535
# core                     0.846535
# dtype: float64, Latency-SLA: Time                     0.133663
# Model Name               0.133663
# File Name                0.133663
# Propagation Delay (s)    0.133663
# Processing Delay (ms)    0.133663
# E2E Delay (s)            0.133663
# location                 0.133663
# core                     0.133663
# dtype: float64

# %%
sla8_prokube = df8_prokube[df8_prokube['E2E Delay (s)'] > 1].count()/ df8_prokube['E2E Delay (s)'].count()
sla8_cost = df8_costgreedy[df8_costgreedy['E2E Delay (s)'] > 1].count()/ df8_costgreedy['E2E Delay (s)'].count()
sla8_latency = df8_latencygreedy[df8_latencygreedy['E2E Delay (s)'] > 1].count()/ df8_latencygreedy['E2E Delay (s)'].count()
print(f'Pro-SLA: {sla8_prokube}, Cost-SLA: {sla8_cost}, Latency-SLA: {sla8_latency}')
# Out:
# Pro-SLA: Time                     0.190299
# Model Name               0.190299
# File Name                0.190299
# Propagation Delay (s)    0.190299
# Processing Delay (ms)    0.190299
# E2E Delay (s)            0.190299
# location                 0.190299
# core                     0.190299
# dtype: float64, Cost-SLA: Time                     0.872525
# Model Name               0.872525
# File Name                0.872525
# Propagation Delay (s)    0.872525
# Processing Delay (ms)    0.872525
# E2E Delay (s)            0.872525
# location                 0.872525
# core                     0.872525
# dtype: float64, Latency-SLA: Time                     0.262376
# Model Name               0.262376
# File Name                0.262376
# Propagation Delay (s)    0.262376
# Processing Delay (ms)    0.262376
# E2E Delay (s)            0.262376
# location                 0.262376
# core                     0.262376
# dtype: float64

# %%
# Sample data (replace with your actual data)
models = ['PK', 'CG', 'LG']
containers = ['Four', 'Eight']
overall_sla_rates = {
    'PK': [sla4_prokube[0], sla8_prokube[0]],  # Replace with actual values
    'CG': [sla4_cost[0], sla8_cost[0]],  # Replace with actual values
    'LG': [sla4_latency[0], sla8_latency[0]]   # Replace with actual values
}

fig, ax = plt.subplots(figsize=(7, 4))

bar_width = 0.25
index = np.arange(len(containers))

for i, model in enumerate(models):
    bars = [overall_sla_rates[model][j] for j in range(len(containers))]
    ax.bar(index + i * bar_width, bars, bar_width, label=model)

ax.set_xlabel('Container Configurations')
ax.set_ylabel('SLA Violation Rate')
#ax.set_title('SLA Violation Rates for Different Models and Container Configurations')
ax.set_xticks(index + 1 * bar_width)  # Adjust the position of xticks
ax.set_xticklabels(containers)
ax.legend()

plt.tight_layout()
plt.grid(True)
plt.ylim([0,1])
plt.savefig('sla_violation.pdf', format='pdf')

plt.show()

# %%
server_columns = ['migrations', 'scalings', 'cost']

# %%
df8_prokube_server = pd.read_csv('eight_containers_75/ServerStat_1713524976.4174697.csv', header=None, names=server_columns)
df8_cost_server = pd.read_csv('eight_containers_75/ServerStat_1714059688.0958374_CostGreedy.csv', header=None, names=server_columns)
df8_latency_server = pd.read_csv('eight_containers_75/ServerStat_1714070506.0299976_LatencyGreedy.csv', header=None, names=server_columns)
print(f'Prokube: {df8_prokube_server.shape}, Cost: {df8_cost_server.shape}, Latency: {df8_latency_server.shape}')
# Out:
# Prokube: (101, 3), Cost: (101, 3), Latency: (101, 3)

# %%
round(df_eight_server_p75['scalings'].sum()/df_eight_server_p75['scalings'].count(), ndigits=2)
# Out:
# 0.08

# %%
round(df_eight_server_p75['cost'].sum()/df_eight_server_p75['cost'].count(), ndigits=2)
# Out:
# 7.94

# %%
df_eight_server_p75
# Out:
#      migrations  scalings  cost
# 0             0         0   4.0
# 1             3         4   6.0
# 2             3         4   8.0
# 3             0         0   8.0
# 4             0         0   8.0
# ..          ...       ...   ...
# 96            0         0   8.0
# 97            0         0   8.0
# 98            0         0   8.0
# 99            0         0   8.0
# 100           0         0   8.0
#
# [101 rows x 3 columns]

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))

#ax1.plot(inf_time5.index, inf_time5, label='Inference Time 500m', marker='o')
#ax1.plot(inf_time1.index, inf_time1, label='Inference Time 1 Core', marker='o')
ax1.plot(df4_prokube_server.index, df4_prokube_server['cost'], label='PK - Four')
ax1.plot(df4_cost_server.index, df4_cost_server['cost'], label='CG - Four')
ax1.plot(df4_latency_server.index, df4_latency_server['cost'], label='LG - Four')
ax1.set_ylabel('Cost')
ax1.set_xlabel('Scheduling Interval (t)')
ax1.grid(True)
ax1.legend()
ax1.set_ylim([0,15])

#plt.title('Processing Delay Three Cores')

# Subplot 2: E2E Delay
ax2.plot(df8_prokube_server.index, df8_prokube_server['cost'], label='PK - Eight')
ax2.plot(df8_cost_server.index, df8_cost_server['cost'], label='CG - Eight')
ax2.plot(df8_latency_server.index, df8_latency_server['cost'], label='LG - Eight')
ax2.set_ylabel('Cost')
ax2.set_xlabel('Scheduling Interval (t)')
ax2.set_ylim([0,15])
ax2.grid(True)
ax2.legend(loc='lower right')

plt.subplots_adjust(wspace=0.3)
#plt.suptitle('Processing and E2E Delays Comparison for Yolov5n')
plt.grid(True)
# Adjust layout
plt.tight_layout()

# Show plot
plt.savefig('cost.pdf')
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.plot(df4_prokube_server.index, df4_prokube_server['cost'], label='PK - Four')
plt.plot(df4_cost_server.index, df4_cost_server['cost'], label='CG - Four')
plt.plot(df4_latency_server.index, df4_latency_server['cost'], label='LG - Four')
plt.plot(df8_prokube_server.index, df8_prokube_server['cost'], label='PK - Eight')
plt.plot(df8_cost_server.index, df8_cost_server['cost'], label='CG - Eight')
plt.plot(df8_latency_server.index, df8_latency_server['cost'], label='LG - Eight')
#plt.title('Processing Delay')
plt.xlabel('Scheduling Interval (t)')
plt.ylabel('Cost')
#plt.legend()
plt.grid(True)
plt.ylim([0,15])
plt.legend(loc='lower right')
plt.savefig('cost.pdf', format='pdf')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))

ax1.plot(df4_prokube_server.index, df4_prokube_server['migrations'], label='PK - Four')
ax1.plot(df4_cost_server.index, df4_cost_server['migrations'], label='CG - Four')
ax1.plot(df4_latency_server.index, df4_latency_server['migrations'], label='LG - Four')
ax1.set_ylabel('Migrations Count')
ax1.set_xlabel('Scheduling Interval (t)')
ax1.grid(True)
ax1.legend()
ax1.set_ylim([-0.5,8.5])

#plt.title('Processing Delay Three Cores')

# Subplot 2: E2E Delay
ax2.plot(df8_prokube_server.index, df8_prokube_server['migrations'], label='PK - Eight')
ax2.plot(df8_cost_server.index, df8_cost_server['migrations'], label='CG - Eight')
ax2.plot(df8_latency_server.index, df8_latency_server['migrations'], label='LG - Eight')
ax2.set_ylabel('Migrations Count')
ax2.set_xlabel('Scheduling Interval (t)')
ax2.set_ylim([-0.5,8.5])
ax2.grid(True)
ax2.legend()

plt.subplots_adjust(wspace=0.3)
#plt.suptitle('Processing and E2E Delays Comparison for Yolov5n')
plt.grid(True)
# Adjust layout
plt.tight_layout()

# Show plot
plt.savefig('migrations.pdf')
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.plot(df4_prokube_server.index, df4_prokube_server['migrations'], label='PK - Four')
plt.plot(df4_cost_server.index, df4_cost_server['migrations'], label='CG - Four')
plt.plot(df4_latency_server.index, df4_latency_server['migrations'], label='LG - Four')
plt.plot(df8_prokube_server.index, df8_prokube_server['migrations'], label='PK - Eight')
plt.plot(df8_cost_server.index, df8_cost_server['migrations'], label='CG - Eight')
plt.plot(df8_latency_server.index, df8_latency_server['migrations'], label='LG - Eight')
#plt.title('E2E Delay')
plt.xlabel('Scheduling Interval (t)')
plt.ylabel('Migrations Count')
plt.legend()
plt.grid(True)
#plt.ylim([0,2])
plt.savefig('migrations.pdf', format='pdf')
plt.show()

# %%
df_four_server['migrations']
# Out:
# 0      0
# 1      2
# 2      0
# 3      0
# 4      0
#       ..
# 96     0
# 97     0
# 98     0
# 99     0
# 100    0
# Name: migrations, Length: 101, dtype: int64

# %%
plt.figure(figsize=(8,4))
plt.plot(df_four_server.index, df_four_server['scalings'], label='Scaling - Four')
plt.plot(df_eight_server_p75.index, df_eight_server_p75['scalings'], label='Scaling - Eight')
#plt.title('E2E Delay')
plt.xlabel('Scheduling Interval (t)')
plt.ylabel('Scaling Count')
plt.legend()
plt.grid(True)
#plt.xlim([0,100])
plt.savefig('scalings.pdf', format='pdf')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))

ax1.plot(df4_prokube_server.index, df4_prokube_server['scalings'], label='PK - Four')
ax1.plot(df4_cost_server.index, df4_cost_server['scalings'], label='CG - Four')
ax1.plot(df4_latency_server.index, df4_latency_server['scalings'], label='LG - Four')
ax1.set_ylabel('Vertical Scalings Count')
ax1.set_xlabel('Scheduling Interval (t)')
ax1.grid(True)
ax1.legend()
ax1.set_ylim([-0.5,8.5])

#plt.title('Processing Delay Three Cores')

# Subplot 2: E2E Delay
ax2.plot(df8_prokube_server.index, df8_prokube_server['scalings'], label='PK - Eight')
ax2.plot(df8_cost_server.index, df8_cost_server['scalings'], label='CG - Eight')
ax2.plot(df8_latency_server.index, df8_latency_server['scalings'], label='LG - Eight')
ax2.set_ylabel('Vertical Scalings Count')
ax2.set_xlabel('Scheduling Interval (t)')
ax2.set_ylim([-0.5,8.5])
ax2.grid(True)
ax2.legend()

plt.subplots_adjust(wspace=0.3)
#plt.suptitle('Processing and E2E Delays Comparison for Yolov5n')
plt.grid(True)
# Adjust layout
plt.tight_layout()

# Show plot
plt.savefig('scalings.pdf')
plt.show()
